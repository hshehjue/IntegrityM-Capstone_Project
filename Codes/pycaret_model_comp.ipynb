# %% [markdown]
# # PyCaret to Compare Performance by Models
#
# ### SeungHeon Han

# %%
import pandas as pd
import time
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import glob
import copy
from collections import Counter
from numpy import where
import statsmodels.api as sm
from pycaret.classification import * 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
import random
import itertools
from imblearn import over_sampling
from imblearn import under_sampling
from imblearn.pipeline import Pipeline
import os              # for directory and file manipulation
import numpy as np     # for basic array manipulation
import pandas as pd    # for dataframe manipulation
import datetime        # for timestamp
from sklearn.metrics import accuracy_score, f1_score, log_loss, mean_squared_error, roc_auc_score, roc_curve


# global constants 
ROUND = 3              # generally, insane precision is not needed 

# set global random seed for better reproducibility
SEED = 1234
seed = 1234
np.random.seed(SEED)
NTHREAD = 4

import warnings
warnings.filterwarnings('ignore')

# %%
# import the cleaned dataset 
# %cd /Users/alex/Desktop/Master/BA_Practicum_6217_10/Project/dataset/partB
partB = pd.read_csv("processed_partB.csv")
# Out:
# /Users/alex/Desktop/Master/BA_Practicum_6217_10/Project/dataset/partB

# %%
partB = partB.drop("Avg_Mdcr_Stdzd_Amt", axis=1)
partB.head()
# Out:
#           NPI                          Type Place_Of_Srvc  Tot_Benes  \
# 0  1679548440                   Dermatology             O         25
# 1  1184730848                      Podiatry             O         15
# 2  1700097557          Diagnostic Radiology             F         32
# 3  1659528339  Mass Immunizer Roster Biller             O        112
# 4  1982966685               Family Practice             O        112
#
#    Tot_Srvcs  Tot_Bene_Day_Srvcs  Avg_Sbmtd_Chrg  Avg_Mdcr_Alowd_Amt  \
# 0       46.0                  46      281.000000          128.275435
# 1       19.0                  19       18.962105           18.571579
# 2       32.0                  32       27.000000            9.387187
# 3      114.0                 114        4.940614            4.366404
# 4      114.0                 114       35.000000           25.290000
#
#    Avg_Mdcr_Pymt_Amt  Fraud
# 0         100.793043      0
# 1          13.215263      0
# 2           7.243750      0
# 3           4.366404      0
# 4          25.290000      0

# %% [markdown]
# ### Ratio of Fraud and Non-fraud classes

# %%
fig = plt.figure(figsize=(8, 6))

# Plot the bar graph
Y_fraud = list(partB["Fraud"].value_counts())
X_fraud = ["0", "1"]

plot = plt.bar(X_fraud, Y_fraud, 
               width = 0.4,
              color = "orange",
              alpha = 0.6)
 
# Add the data value on head of the bar
for value in plot:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             1.002*height,'%d' % int(height), ha='center', va='bottom', 
             fontsize = 13)
 
# Add labels and title
plt.title("Labels", fontsize = 20)
plt.xlabel("Label", fontsize = 18)
plt.ylabel("Count", fontsize = 18)
 
# Display the graph on the screen
plt.show()

# %%
ratio = partB["Fraud"].value_counts(normalize = True) 
print("Non-Fraud: ", round(ratio[0]*100, 2), "%")
print("Fraud: ", round(ratio[1]*100, 2), "%")
# Out:
# Non-Fraud:  90.91 %
# Fraud:  9.09 %

# %% [markdown]
# ### Data Spliting

# %%
# Assign X and y features

X_var = list(partB.columns)

for var in ["NPI","Fraud"]:
    X_var.remove(var)

y_var = "Fraud"

# %%
# Split the whole dataset into train and test dataset
# Using a stratified random sampling so that the Fraud-class (1) data are evenly split into train & test sets
x_train, x_test, y_train, y_test = train_test_split(partB[X_var], 
                                                    partB[y_var], 
                                                    test_size=0.1, 
                                                    stratify=partB["Fraud"],
                                                    random_state=SEED)

# Also concatenate the split x & y dataframes 
tr_df = pd.concat([x_train, y_train], axis = 1)
te_df = pd.concat([x_test, y_test], axis = 1)

# %%
# Calculate the odds ratio of Fraud & Non-fraud labels for train & test sets

train_0 = len(tr_df[tr_df["Fraud"] == 0])
train_1 = len(tr_df[tr_df["Fraud"] == 1])

test_0 = len(te_df[te_df["Fraud"] == 0])
test_1 = len(te_df[te_df["Fraud"] == 1])

split_df = pd.DataFrame({"x_axis":["Train", "Test"], 
                         "Ratio":[train_1/train_0, test_1/test_0]})

# %%
fig, ax = plt.subplots(figsize=(8,6))

# Plot the bar graph
plot = plt.bar(split_df["x_axis"], split_df["Ratio"],
               width = 0.4,
              color = "pink",
              alpha = 0.6)
 
# Add the data value on head of the bar
for value in plot:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             1.002*height,'%.5f' % height, ha='center', va='bottom', 
             fontsize = 13)
 
# Add labels and title
plt.title("Odds Ratio of Fraud", fontsize = 20)
plt.xlabel("Set", fontsize = 18)
plt.ylabel("Count", fontsize = 18)

ax.set_xticklabels(split_df["x_axis"], fontsize=18)

# Display the graph on the screen
plt.show()

# %% [markdown]
# ### -----------------SMOTE---------------------

# %%
tr_df.head()
# Out:
#         Tot_Benes  Tot_Srvcs  Tot_Bene_Day_Srvcs  Avg_Sbmtd_Chrg  \
# 348797         12       12.0                  12       66.000000
# 33489          32       51.0                  51      140.000000
# 70149          22       69.0                  69      100.000000
# 151709         40       50.0                  50       30.000000
# 84786          61       62.0                  62      213.629032
#
#         Avg_Mdcr_Alowd_Amt  Avg_Mdcr_Pymt_Amt  \
# 348797           30.146667          24.017500
# 33489            53.551373          38.991765
# 70149            69.400725          53.272464
# 151709           15.430000          15.430000
# 84786           120.259032          65.797581
#
#         Type_Advanced Heart Failure and Transplant Cardiology  \
# 348797                                                  0
# 33489                                                   0
# 70149                                                   0
# 151709                                                  0
# 84786                                                   0
#
#         Type_All Other Suppliers  Type_Allergy/ Immunology  \
# 348797                         0                         0
# 33489                          0                         0
# 70149                          0                         0
# 151709                         0                         0
# 84786                          0                         0
#
#         Type_Allergy/Immunology  ...  Type_Thoracic Surgery  \
# 348797                        0  ...                      0
# 33489                         0  ...                      0
# 70149                         0  ...                      0
# 151709                        0  ...                      0
# 84786                         0  ...                      0
#
#         Type_Undefined Physician type  Type_Undersea and Hyperbaric Medicine  \
# 348797                              0                                      0
# 33489                               0                                      0
# 70149                               0                                      0
# 151709                              0                                      0
# 84786                               0                                      0
#
#         Type_Unknown Physician Specialty Code  Type_Unknown Supplier/Provider  \
# 348797                                      0                               0
# 33489                                       0                               0
# 70149                                       0                               0
# 151709                                      0                               0
# 84786                                       0                               0
#
#         Type_Unknown Supplier/Provider Specialty  Type_Urology  \
# 348797                                         0             0
# 33489                                          0             0
# 70149                                          0             0
# 151709                                         0             0
# 84786                                          0             0
#
#         Type_Vascular Surgery  Place_Of_Srvc  Fraud
# 348797                      0              1      1
# 33489                       0              1      0
# 70149                       0              1      0
# 151709                      0              1      0
# 84786                       0              1      0
#
# [5 rows x 130 columns]

# %% [markdown]
# ### Scatter Plot of The Imbalanced Data

# %%
# scatter plot of the imbalanced data
# x-axis = "Tot_Benes_mean"
# y-axis = "Tot_Bene_Day_Srvcs_mean"

plt.figure(figsize=(10, 10))

counter = Counter(tr_df[y_var])
for label, _ in counter.items():
    row_ix = where(tr_df[y_var] == label)[0]
    plt.scatter(tr_df[X_var].iloc[row_ix, 3], 
                tr_df[X_var].iloc[row_ix, 4], 
                label=str(label))

plt.title("Trainset", fontsize = 18)
plt.xlabel("Avg_Sbmtd_Chrg", fontsize = 15)
plt.ylabel("Avg_Mdcr_Alowd_Amt", fontsize = 15)
plt.legend()
plt.show()

# %% [markdown]
# ### Over-Sampling the random_undersampled imbalnaced data through SMOTE

# %%
# to SMOTE, temporarily convert categorical variable ('Type') to numerical values
dic = dict(zip(tr_df["Type"].unique().tolist(), np.arange(len(tr_df["Type"].unique().tolist())).tolist()))

tr_df['Type'] = tr_df['Type'].map(dic)

tr_df['Type'] = tr_df['Type'].astype('uint8')

tr_df = pd.get_dummies(tr_df, drop_first = True)
tr_df = tr_df.rename(columns = {"Place_Of_Srvc_O":"Place_Of_Srvc"})

# %%
# SMOTE
from imblearn.over_sampling import SMOTE
oversample = over_sampling.SMOTE(sampling_strategy = 0.5, random_state = SEED)
tr_X, tr_y = oversample.fit_resample(tr_df[X_var], tr_df[y_var])

# %%
# Convert the numerical values of the categorical variable back to the categorical values
inv_dic = dict([(val, key) for key, val in dic.items()])
tr_X['Type'] = tr_X['Type'].map(inv_dic)

place_dic = {1:"O", 0:"F"}
tr_X["Place_Of_Srvc"] = tr_X["Place_Of_Srvc"].map(place_dic)

tr_X
# Out:
#                         Type  Place_Of_Srvc  Tot_Benes   Tot_Srvcs  \
# 0                  Optometry              1         12   12.000000
# 1         Orthopedic Surgery              1         32   51.000000
# 2                   Podiatry              1         22   69.000000
# 3            Family Practice              1         40   50.000000
# 4       Diagnostic Radiology              1         61   62.000000
# ...                      ...            ...        ...         ...
# 454108         Ophthalmology              1        147  255.692779
# 454109   Clinical Laboratory              0         34   38.369616
# 454110      General Practice              1         37   50.802209
# 454111             Neurology              0         13   15.481264
# 454112  Diagnostic Radiology              1         40  190.072236
#
#         Tot_Bene_Day_Srvcs  Avg_Sbmtd_Chrg  Avg_Mdcr_Alowd_Amt  \
# 0                       12       66.000000           30.146667
# 1                       51      140.000000           53.551373
# 2                       69      100.000000           69.400725
# 3                       50       30.000000           15.430000
# 4                       62      213.629032          120.259032
# ...                    ...             ...                 ...
# 454108                 255      128.006565           64.463305
# 454109                  38       83.821704           48.867890
# 454110                  50       21.216652            2.959866
# 454111                  15     1494.164225          778.362439
# 454112                 151       27.659493           23.223138
#
#         Avg_Mdcr_Pymt_Amt
# 0               24.017500
# 1               38.991765
# 2               53.272464
# 3               15.430000
# 4               65.797581
# ...                   ...
# 454108          46.706498
# 454109          36.991454
# 454110           2.959866
# 454111         620.158113
# 454112          17.770354
#
# [454113 rows x 8 columns]

# %%
plt.figure(figsize=(14, 6))
plt.subplot(121)

# Plot the bar graph for the original train
Y_fraud = list(y_train.value_counts())
Labels = ["0", "1"]

plot = plt.bar(Labels, Y_fraud, 
               width = 0.4,
              color = "blue",
              alpha = 0.6)
 
# Add the data value on head of the bar
for value in plot:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             1.002*height,'%d' % int(height), ha='center', va='bottom', 
             fontsize = 13)

# Add labels and title
plt.title("Original", fontsize = 20)
plt.xlabel("Label", fontsize = 18)
plt.ylabel("Frequency", fontsize = 18)


plt.subplot(122)

# Plot the bar graph for the over-sampled train
Y_fraud_smote = list(tr_y.value_counts())

plot_smote = plt.bar(Labels, Y_fraud_smote, 
               width = 0.4,
              color = "orange",
              alpha = 0.6)
 
# Add the data value on head of the bar
for value in plot_smote:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             1.002*height,'%d' % int(height), ha='center', va='bottom', 
             fontsize = 13)

# Add labels and title
plt.title("SMOTE", fontsize = 20)
plt.xlabel("Label", fontsize = 18)

# Display the graph on the screen
plt.show()

# %%
# scatter plot of the data transformed by SMOTE 
# x-axis = "Tot_Benes_mean"
# y-axis = "Tot_Bene_Day_Srvcs_mean"

plt.figure(figsize=(10, 10))

counter = Counter(tr_y)
for label, _ in counter.items():
    row_ix = where(tr_y == label)[0]
    plt.scatter(tr_X.iloc[row_ix, 3], tr_X.iloc[row_ix, 4], label=str(label))

plt.title("Oversampled Trainset", fontsize = 18)
plt.xlabel("Avg_Sbmtd_Chrg", fontsize = 15)
plt.ylabel("Avg_Mdcr_Alowd_Amt", fontsize = 15)
plt.legend()
plt.show()

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Data Partitioning (Train & Valid)

# %%
trans_tr_df = pd.concat([tr_X, tr_y], axis = 1)

# %%
# Split train and validation sets 
np.random.seed(SEED)

ratio = 0.8 # split train & validation sets with 7:3 ratio 

split = np.random.rand(len(trans_tr_df)) < ratio # define indices of 70% corresponding to the training set

train = trans_tr_df[split]
valid = trans_tr_df[~split]

# summarize split
print('Train data rows = %d, columns = %d' % (train.shape[0], train.shape[1]))
print('Validation data rows = %d, columns = %d' % (valid.shape[0], valid.shape[1]))
# Out:
# Train data rows = 363675, columns = 10
# Validation data rows = 90438, columns = 10

# %% [markdown]
# ## PyCaret

# %%
trans_tr_df
# Out:
#                         Type  Place_Of_Srvc  Tot_Benes   Tot_Srvcs  \
# 0                  Optometry              1         12   12.000000
# 1         Orthopedic Surgery              1         32   51.000000
# 2                   Podiatry              1         22   69.000000
# 3            Family Practice              1         40   50.000000
# 4       Diagnostic Radiology              1         61   62.000000
# ...                      ...            ...        ...         ...
# 454108         Ophthalmology              1        147  255.692779
# 454109   Clinical Laboratory              0         34   38.369616
# 454110      General Practice              1         37   50.802209
# 454111             Neurology              0         13   15.481264
# 454112  Diagnostic Radiology              1         40  190.072236
#
#         Tot_Bene_Day_Srvcs  Avg_Sbmtd_Chrg  Avg_Mdcr_Alowd_Amt  \
# 0                       12       66.000000           30.146667
# 1                       51      140.000000           53.551373
# 2                       69      100.000000           69.400725
# 3                       50       30.000000           15.430000
# 4                       62      213.629032          120.259032
# ...                    ...             ...                 ...
# 454108                 255      128.006565           64.463305
# 454109                  38       83.821704           48.867890
# 454110                  50       21.216652            2.959866
# 454111                  15     1494.164225          778.362439
# 454112                 151       27.659493           23.223138
#
#         Avg_Mdcr_Pymt_Amt  Fraud
# 0               24.017500      1
# 1               38.991765      0
# 2               53.272464      0
# 3               15.430000      0
# 4               65.797581      0
# ...                   ...    ...
# 454108          46.706498      1
# 454109          36.991454      1
# 454110           2.959866      1
# 454111         620.158113      1
# 454112          17.770354      1
#
# [454113 rows x 9 columns]

# %%
trans_tr_df
# Out:
#                         Type Place_Of_Srvc  Tot_Benes   Tot_Srvcs  \
# 0                  Optometry             O         12   12.000000
# 1         Orthopedic Surgery             O         32   51.000000
# 2                   Podiatry             O         22   69.000000
# 3            Family Practice             O         40   50.000000
# 4       Diagnostic Radiology             O         61   62.000000
# ...                      ...           ...        ...         ...
# 454108         Ophthalmology             O        147  255.692779
# 454109   Clinical Laboratory             F         34   38.369616
# 454110      General Practice             O         37   50.802209
# 454111             Neurology             F         13   15.481264
# 454112  Diagnostic Radiology             O         40  190.072236
#
#         Tot_Bene_Day_Srvcs  Avg_Sbmtd_Chrg  Avg_Mdcr_Alowd_Amt  \
# 0                       12       66.000000           30.146667
# 1                       51      140.000000           53.551373
# 2                       69      100.000000           69.400725
# 3                       50       30.000000           15.430000
# 4                       62      213.629032          120.259032
# ...                    ...             ...                 ...
# 454108                 255      128.006565           64.463305
# 454109                  38       83.821704           48.867890
# 454110                  50       21.216652            2.959866
# 454111                  15     1494.164225          778.362439
# 454112                 151       27.659493           23.223138
#
#         Avg_Mdcr_Pymt_Amt  Fraud
# 0               24.017500      1
# 1               38.991765      0
# 2               53.272464      0
# 3               15.430000      0
# 4               65.797581      0
# ...                   ...    ...
# 454108          46.706498      1
# 454109          36.991454      1
# 454110           2.959866      1
# 454111         620.158113      1
# 454112          17.770354      1
#
# [454113 rows x 9 columns]

# %%
train = setup(data = trans_tr_df, target = "Fraud")
# Out:
# <style type="text/css">
# #T_46435_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_46435">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46435_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_46435_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46435_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46435_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_46435_row0_col1" class="data row0 col1" >8748</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_46435_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_46435_row1_col1" class="data row1 col1" >Fraud</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_46435_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_46435_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_46435_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_46435_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_46435_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_46435_row4_col1" class="data row4 col1" >(454113, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_46435_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_46435_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_46435_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_46435_row6_col1" class="data row6 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_46435_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_46435_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_46435_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_46435_row8_col1" class="data row8 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_46435_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_46435_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_46435_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_46435_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_46435_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_46435_row11_col1" class="data row11 col1" >(317879, 126)</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_46435_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_46435_row12_col1" class="data row12 col1" >(136234, 126)</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_46435_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_46435_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_46435_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_46435_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_46435_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_46435_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_46435_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_46435_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_46435_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_46435_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_46435_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_46435_row18_col1" class="data row18 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_46435_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_46435_row19_col1" class="data row19 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_46435_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_46435_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_46435_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_46435_row21_col1" class="data row21 col1" >f7d4</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_46435_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_46435_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_46435_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_46435_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_46435_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_46435_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_46435_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_46435_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_46435_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_46435_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_46435_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_46435_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_46435_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_46435_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_46435_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_46435_row29_col1" class="data row29 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_46435_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_46435_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_46435_row30_col1" class="data row30 col1"
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 train = setup(data = trans_tr_df, target = "Fraud")
#
# File /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/pycaret/classification.py:595, in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     592 if log_plots == True:
#     593     log_plots = ["auc", "confusion_matrix", "feature"]
# --> 595 return pycaret.internal.tabular.setup(
#     596     ml_usecase="classification",
#     597     available_plots=available_plots,
#     598     data=data,
#     599     target=target,
#     600     train_size=train_size,
#     601     test_data=test_data,
#     602     preprocess=preprocess,
#     603     imputation_type=imputation_type,
#     604     iterative_imputation_iters=iterative_imputation_iters,
#     605     categorical_features=categorical_features,
#     606     categorical_imputation=categorical_imputation,
#     607     categorical_iterative_imputer=categorical_iterative_imputer,
#     608     ordinal_features=ordinal_features,
#     609     high_cardinality_features=high_cardinality_features,
#     610     high_cardinality_method=high_cardinality_method,
#     611     numeric_features=numeric_features,
#     612     numeric_imputation=numeric_imputation,
#     613     numeric_iterative_imputer=numeric_iterative_imputer,
#     614     date_features=date_features,
#     615     ignore_features=ignore_features,
#     616     normalize=normalize,
#     617     normalize_method=normalize_method,
#     618     transformation=transformation,
#     619     transformation_method=transformation_method,
#     620     handle_unknown_categorical=handle_unknown_categorical,
#     621     unknown_categorical_method=unknown_categorical_method,
#     622     pca=pca,
#     623     pca_method=pca_method,
#     624     pca_components=pca_components,
#     625     ignore_low_variance=ignore_low_variance,
#     626     combine_rare_levels=combine_rare_levels,
#     627     rare_level_threshold=rare_level_threshold,
#     628     bin_numeric_features=bin_numeric_features,
#     629     remove_outliers=remove_outliers,
#     630     outliers_threshold=outliers_threshold,
#     631     remove_multicollinearity=remove_multicollinearity,
#     632     multicollinearity_threshold=multicollinearity_threshold,
#     633     remove_perfect_collinearity=remove_perfect_collinearity,
#     634     create_clusters=create_clusters,
#     635     cluster_iter=cluster_iter,
#     636     polynomial_features=polynomial_features,
#     637     polynomial_degree=polynomial_degree,
#     638     trigonometry_features=trigonometry_features,
#     639     polynomial_threshold=polynomial_threshold,
#     640     group_features=group_features,
#     641     group_names=group_names,
#     642     feature_selection=feature_selection,
#     643     feature_selection_threshold=feature_selection_threshold,
#     644     feature_selection_method=feature_selection_method,
#     645     feature_interaction=feature_interaction,
#     646     feature_ratio=feature_ratio,
#     647     interaction_threshold=interaction_threshold,
#     648     fix_imbalance=fix_imbalance,
#     649     fix_imbalance_method=fix_imbalance_method,
#     650     data_split_shuffle=data_split_shuffle,
#     651     data_split_stratify=data_split_stratify,
#     652     fold_strategy=fold_strategy,
#     653     fold=fold,
#     654     fold_shuffle=fold_shuffle,
#     655     fold_groups=fold_groups,
#     656     n_jobs=n_jobs,
#     657     use_gpu=use_gpu,
#     658     custom_pipeline=custom_pipeline,
#     659     html=html,
#     660     session_id=session_id,
#     661     log_experiment=log_experiment,
#     662     experiment_name=experiment_name,
#     663     experiment_custom_tags=experiment_custom_tags,
#     664     log_plots=log_plots,
#     665     log_profile=log_profile,
#     666     log_data=log_data,
#     667     silent=silent,
#     668     verbose=verbose,
#     669     profile=profile,
#     670     profile_kwargs=profile_kwargs,
#     671 )
#
# File /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/pycaret/internal/tabular.py:1775, in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1771 logger.info("setup() succesfully completed......................................")
#    1773 gc.collect()
# -> 1775 return tuple([globals()[v] for v in pycaret_globals])
#
# File /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/pycaret/internal/tabular.py:1775, in <listcomp>(.0)
#    1771 logger.info("setup() succesfully completed......................................")
#    1773 gc.collect()
# -> 1775 return tuple([globals()[v] for v in pycaret_globals])
#
# KeyError: 'dashboard_logger'

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_f790d th {
#   text-align: left;
# }
# #T_f790d_row0_col0, #T_f790d_row0_col3, #T_f790d_row0_col4, #T_f790d_row1_col0, #T_f790d_row1_col1, #T_f790d_row1_col2, #T_f790d_row1_col3, #T_f790d_row1_col4, #T_f790d_row1_col5, #T_f790d_row1_col6, #T_f790d_row1_col7, #T_f790d_row2_col0, #T_f790d_row2_col1, #T_f790d_row2_col2, #T_f790d_row2_col3, #T_f790d_row2_col5, #T_f790d_row2_col6, #T_f790d_row2_col7, #T_f790d_row3_col0, #T_f790d_row3_col1, #T_f790d_row3_col2, #T_f790d_row3_col3, #T_f790d_row3_col4, #T_f790d_row3_col5, #T_f790d_row3_col6, #T_f790d_row3_col7, #T_f790d_row4_col0, #T_f790d_row4_col1, #T_f790d_row4_col2, #T_f790d_row4_col3, #T_f790d_row4_col4, #T_f790d_row4_col5, #T_f790d_row4_col6, #T_f790d_row4_col7, #T_f790d_row5_col0, #T_f790d_row5_col1, #T_f790d_row5_col2, #T_f790d_row5_col3, #T_f790d_row5_col4, #T_f790d_row5_col5, #T_f790d_row5_col6, #T_f790d_row5_col7, #T_f790d_row6_col0, #T_f790d_row6_col1, #T_f790d_row6_col2, #T_f790d_row6_col3, #T_f790d_row6_col4, #T_f790d_row6_col5, #T_f790d_row6_col6, #T_f790d_row6_col7, #T_f790d_row7_col0, #T_f790d_row7_col1, #T_f790d_row7_col2, #T_f790d_row7_col3, #T_f790d_row7_col4, #T_f790d_row7_col5, #T_f790d_row7_col6, #T_f790d_row7_col7, #T_f790d_row8_col0, #T_f790d_row8_col1, #T_f790d_row8_col2, #T_f790d_row8_col3, #T_f790d_row8_col4, #T_f790d_row8_col5, #T_f790d_row8_col6, #T_f790d_row8_col7, #T_f790d_row9_col0, #T_f790d_row9_col1, #T_f790d_row9_col2, #T_f790d_row9_col3, #T_f790d_row9_col4, #T_f790d_row9_col5, #T_f790d_row9_col6, #T_f790d_row9_col7, #T_f790d_row10_col0, #T_f790d_row10_col1, #T_f790d_row10_col2, #T_f790d_row10_col3, #T_f790d_row10_col4, #T_f790d_row10_col5, #T_f790d_row10_col6, #T_f790d_row10_col7, #T_f790d_row11_col0, #T_f790d_row11_col1, #T_f790d_row11_col2, #T_f790d_row11_col3, #T_f790d_row11_col4, #T_f790d_row11_col5, #T_f790d_row11_col6, #T_f790d_row11_col7, #T_f790d_row12_col0, #T_f790d_row12_col1, #T_f790d_row12_col2, #T_f790d_row12_col3, #T_f790d_row12_col4, #T_f790d_row12_col5, #T_f790d_row12_col6, #T_f790d_row12_col7, #T_f790d_row13_col0, #T_f790d_row13_col1, #T_f790d_row13_col2, #T_f790d_row13_col3, #T_f790d_row13_col4, #T_f790d_row13_col5, #T_f790d_row13_col6, #T_f790d_row13_col7, #T_f790d_row14_col0, #T_f790d_row14_col1, #T_f790d_row14_col2, #T_f790d_row14_col3, #T_f790d_row14_col4, #T_f790d_row14_col5, #T_f790d_row14_col6, #T_f790d_row14_col7, #T_f790d_row15_col0, #T_f790d_row15_col1, #T_f790d_row15_col2, #T_f790d_row15_col4, #T_f790d_row15_col5, #T_f790d_row15_col6, #T_f790d_row15_col7 {
#   text-align: left;
# }
# #T_f790d_row0_col1, #T_f790d_row0_col2, #T_f790d_row0_col5, #T_f790d_row0_col6, #T_f790d_row0_col7, #T_f790d_row2_col4, #T_f790d_row15_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f790d_row0_col8, #T_f790d_row1_col8, #T_f790d_row2_col8, #T_f790d_row3_col8, #T_f790d_row4_col8, #T_f790d_row5_col8, #T_f790d_row6_col8, #T_f790d_row7_col8, #T_f790d_row8_col8, #T_f790d_row9_col8, #T_f790d_row10_col8, #T_f790d_row11_col8, #T_f790d_row13_col8, #T_f790d_row14_col8, #T_f790d_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f790d_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f790d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f790d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f790d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f790d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f790d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f790d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f790d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f790d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f790d_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_f790d_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f790d_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_f790d_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_f790d_row0_col1" class="data row0 col1" >0.8692</td>
#       <td id="T_f790d_row0_col2" class="data row0 col2" >0.9277</td>
#       <td id="T_f790d_row0_col3" class="data row0 col3" >0.7449</td>
#       <td id="T_f790d_row0_col4" class="data row0 col4" >0.8441</td>
#       <td id="T_f790d_row0_col5" class="data row0 col5" >0.7914</td>
#       <td id="T_f790d_row0_col6" class="data row0 col6" >0.6967</td>
#       <td id="T_f790d_row0_col7" class="data row0 col7" >0.6996</td>
#       <td id="T_f790d_row0_col8" class="data row0 col8" >24.5340</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_f790d_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_f790d_row1_col1" class="data row1 col1" >0.8642</td>
#       <td id="T_f790d_row1_col2" class="data row1 col2" >0.9220</td>
#       <td id="T_f790d_row1_col3" class="data row1 col3" >0.7386</td>
#       <td id="T_f790d_row1_col4" class="data row1 col4" >0.8347</td>
#       <td id="T_f790d_row1_col5" class="data row1 col5" >0.7837</td>
#       <td id="T_f790d_row1_col6" class="data row1 col6" >0.6852</td>
#       <td id="T_f790d_row1_col7" class="data row1 col7" >0.6880</td>
#       <td id="T_f790d_row1_col8" class="data row1 col8" >34.1870</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_f790d_row2_col0" class="data row2 col0" >CatBoost Classifier</td>
#       <td id="T_f790d_row2_col1" class="data row2 col1" >0.8489</td>
#       <td id="T_f790d_row2_col2" class="data row2 col2" >0.9095</td>
#       <td id="T_f790d_row2_col3" class="data row2 col3" >0.6494</td>
#       <td id="T_f790d_row2_col4" class="data row2 col4" >0.8631</td>
#       <td id="T_f790d_row2_col5" class="data row2 col5" >0.7411</td>
#       <td id="T_f790d_row2_col6" class="data row2 col6" >0.6374</td>
#       <td id="T_f790d_row2_col7" class="data row2 col7" >0.6503</td>
#       <td id="T_f790d_row2_col8" class="data row2 col8" >12.2990</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_f790d_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_f790d_row3_col1" class="data row3 col1" >0.8240</td>
#       <td id="T_f790d_row3_col2" class="data row3 col2" >0.8862</td>
#       <td id="T_f790d_row3_col3" class="data row3 col3" >0.5839</td>
#       <td id="T_f790d_row3_col4" class="data row3 col4" >0.8388</td>
#       <td id="T_f790d_row3_col5" class="data row3 col5" >0.6885</td>
#       <td id="T_f790d_row3_col6" class="data row3 col6" >0.5713</td>
#       <td id="T_f790d_row3_col7" class="data row3 col7" >0.5895</td>
#       <td id="T_f790d_row3_col8" class="data row3 col8" >42.1820</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_f790d_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_f790d_row4_col1" class="data row4 col1" >0.8142</td>
#       <td id="T_f790d_row4_col2" class="data row4 col2" >0.7958</td>
#       <td id="T_f790d_row4_col3" class="data row4 col3" >0.7408</td>
#       <td id="T_f790d_row4_col4" class="data row4 col4" >0.7127</td>
#       <td id="T_f790d_row4_col5" class="data row4 col5" >0.7264</td>
#       <td id="T_f790d_row4_col6" class="data row4 col6" >0.5858</td>
#       <td id="T_f790d_row4_col7" class="data row4 col7" >0.5861</td>
#       <td id="T_f790d_row4_col8" class="data row4 col8" >3.2320</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_f790d_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f790d_row5_col1" class="data row5 col1" >0.8120</td>
#       <td id="T_f790d_row5_c
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.28338e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.34204e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.27969e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.42536e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.64849e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.27995e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.27251e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.28335e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.5896e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.80115e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret_model_comp/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)

# %%
print(best)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=8748, verbose=0,
#                        warm_start=False)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
def max_f1(testset, res):
    pred_prob = model.predict_proba(testset[X_var])
    phat_df = pd.DataFrame([phat[1] for phat in pred_prob], columns = ["phat"])
    temp_df = pd.concat([testset[[y_var]].reset_index(drop=True), phat_df],axis=1)
    
    f1_df = pd.DataFrame(columns = ["cut", "f1_score"])
    
    for cut in np.arange(0, 1+res, res):
        temp_df["pred"] = np.where(temp_df["phat"] > cut, 1, 0)
        f1 = f1_score(temp_df["Fraud"], temp_df["pred"])
        f1_df = f1_df.append({"cut":cut, 
                              "f1_score":f1}, 
                             ignore_index=True)
        
    max_f1 = f1_df.loc[f1_df["f1_score"] == f1_df["f1_score"].max()]
    return max_f1

max_f1 = max_f1(te_df, 0.01)
max_f1
# Out:
#      cut  f1_score
# 42  0.42  0.391166

# %%
model.best_params_
# Out:
# {'depth': 7,
#  'devices': '0:1',
#  'eval_metric': 'F1',
#  'iterations': 3000,
#  'learning_rate': 0.1,
#  'od_type': 'Iter',
#  'od_wait': 500,
#  'random_seed': 1234,
#  'task_type': 'GPU',
#  'verbose': 200}

# %%
best_params = {'depth': 7,
               'devices': '0:1',
               'eval_metric': 'F1',
               'iterations': 5000,
               'learning_rate': 0.1,
               'od_type': 'Iter',
               'od_wait': 500,
               'random_seed': 1234,
               'task_type': 'GPU',
               'verbose': 200}
best_cat = CatBoostClassifier(**best_params)
best_cat.fit(train[X_var], train[y_var], 
          cat_features = ["Type"],
          eval_set=(valid[X_var], valid[y_var]),
          use_best_model=True)
# Out:
# 0:	learn: 0.3989934	test: 0.4052724	best: 0.4052724 (0)	total: 30.2ms	remaining: 2m 30s
# 200:	learn: 0.6603004	test: 0.6579764	best: 0.6579764 (200)	total: 5.63s	remaining: 2m 14s
# 400:	learn: 0.6979467	test: 0.6920769	best: 0.6921237 (399)	total: 11.2s	remaining: 2m 8s
# 600:	learn: 0.7202178	test: 0.7099595	best: 0.7100370 (598)	total: 16.8s	remaining: 2m 3s
# 800:	learn: 0.7353218	test: 0.7205112	best: 0.7205293 (793)	total: 22.4s	remaining: 1m 57s
# 1000:	learn: 0.7483020	test: 0.7296311	best: 0.7296311 (1000)	total: 28s	remaining: 1m 51s
# 1200:	learn: 0.7578678	test: 0.7362463	best: 0.7363628 (1199)	total: 33.6s	remaining: 1m 46s
# 1400:	learn: 0.7661938	test: 0.7419242	best: 0.7419870 (1398)	total: 39.2s	remaining: 1m 40s
# 1600:	learn: 0.7736655	test: 0.7471052	best: 0.7471462 (1599)	total: 44.9s	remaining: 1m 35s
# 1800:	learn: 0.7805588	test: 0.7516774	best: 0.7518375 (1791)	total: 50.5s	remaining: 1m 29s
# 2000:	learn: 0.7876706	test: 0.7553600	best: 0.7555685 (1998)	total: 56.1s	remaining: 1m 24s
# 2200:	learn: 0.7934090	test: 0.7586708	best: 0.7586933 (2199)	total: 1m 1s	remaining: 1m 18s
# 2400:	learn: 0.7989633	test: 0.7632598	best: 0.7632598 (2400)	total: 1m 7s	remaining: 1m 12s
# 2600:	learn: 0.8039335	test: 0.7662232	best: 0.7662232 (2600)	total: 1m 12s	remaining: 1m 7s
# 2800:	learn: 0.8086931	test: 0.7680441	best: 0.7680519 (2741)	total: 1m 18s	remaining: 1m 1s
# 3000:	learn: 0.8133038	test: 0.7706567	best: 0.7708146 (2994)	total: 1m 24s	remaining: 56s
# 3200:	learn: 0.8171437	test: 0.7729436	best: 0.7731853 (3178)	total: 1m 29s	remaining: 50.3s
# 3400:	learn: 0.8213857	test: 0.7756565	best: 0.7757363 (3396)	total: 1m 35s	remaining: 44.7s
# 3600:	learn: 0.8254149	test: 0.7780184	best: 0.7780244 (3590)	total: 1m 40s	remaining: 39.2s
# 3800:	learn: 0.8296114	test: 0.7798344	best: 0.7798344 (3800)	total: 1m 46s	remaining: 33.6s
# 4000:	learn: 0.8333110	test: 0.7818039	best: 0.7818039 (4000)	total: 1m 52s	remaining: 28s
# 4200:	learn: 0.8364583	test: 0.7822346	best: 0.7822346 (4196)	total: 1m 57s	remaining: 22.4s
# 4400:	learn: 0.8396302	test: 0.7841158	best: 0.7841158 (4400)	total: 2m 3s	remaining: 16.8s
# 4600:	learn: 0.8429964	test: 0.7861644	best: 0.7861644 (4600)	total: 2m 8s	remaining: 11.2s
# 4800:	learn: 0.8460861	test: 0.7876416	best: 0.7877926 (4799)	total: 2m 14s	remaining: 5.57s
# 4999:	learn: 0.8489096	test: 0.7889011	best: 0.7889562 (4991)	total: 2m 19s	remaining: 0us
# bestTest = 0.7889562481
# bestIteration = 4991
# Shrink model to first 4992 iterations.

# %%
def max_f1(testset, res):
    pred_prob = best_cat.predict_proba(testset[X_var])
    phat_df = pd.DataFrame([phat[1] for phat in pred_prob], columns = ["phat"])
    temp_df = pd.concat([testset[[y_var]].reset_index(drop=True), phat_df],axis=1)
    
    f1_df = pd.DataFrame(columns = ["cut", "f1_score"])
    
    for cut in np.arange(0, 1+res, res):
        temp_df["pred"] = np.where(temp_df["phat"] > cut, 1, 0)
        f1 = f1_score(temp_df["Fraud"], temp_df["pred"])
        f1_df = f1_df.append({"cut":cut, 
                              "f1_score":f1}, 
                             ignore_index=True)
        
    max_f1 = f1_df.loc[f1_df["f1_score"] == f1_df["f1_score"].max()]
    return max_f1

max_f1 = max_f1(te_df, 0.01)
max_f1
# Out:
#      cut  f1_score
# 37  0.37  0.390517

# %%
import shap
from catboost import Pool
shap_values = best_cat.get_feature_importance(Pool(te_df[X_var], label = y_test, cat_features = ["Type"]), 
                                                 type='ShapValues')

# %%
expected_value = shap_values[0,-1]
shap_values = shap_values[:,:-1]
shap.initjs()
shap.force_plot(expected_value, shap_values[0:], te_df[X_var].iloc[0:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
shap_values[:,:-1]
# Out:
# array([[-0.27679471,  0.00501182, -0.10030114, ...,  0.07565451,
#          0.0263282 ,  0.32600871],
#        [-0.15042962,  0.29833129, -0.14709196, ...,  0.06408882,
#          0.02708518, -0.25183884],
#        [ 0.25504208, -1.20874882,  0.2952648 , ...,  0.06968892,
#          0.02648236,  0.1467409 ],
#        ...,
#        [-0.08136786, -0.16704825, -0.14457482, ...,  0.06796119,
#          0.02685951, -0.27616594],
#        [ 0.08655711, -0.63933106,  0.09405157, ...,  0.07488803,
#          0.02566137, -0.19404147],
#        [-0.01937231, -0.39696042,  0.03279072, ...,  0.07189636,
#          0.02519172,  0.15126236]])
